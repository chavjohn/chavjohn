# %% [markdown]
# <a href="https://colab.research.google.com/github/chavjohn/chavjohn/blob/main/Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Objective: Use dataset from https://covidtracking.com/data/download to analyze how many Whites vs. Blacks died from Covid19 in 2021 in NY?

# %% [markdown]
# Simple Data Visualization with pandas

# %%
import pandas as pd
from google.colab import files

# %% [markdown]
# Uploading and Reading Dataset file

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb60fd7a-024b-40ea-84b3-df9dadf9169d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb60fd7a-024b-40ea-84b3-df9dadf9169d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CRDT Data NY- CRDT.csv to CRDT Data NY- CRDT (6).csv

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length= len (uploaded[fn])))
# Out:
# User uploaded file "CRDT Data NY- CRDT.csv" with length 547 bytes

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['CRDT Data NY- CRDT.csv']))
print(df)
# Out:
#          Date  Unnamed: 1  Unnamed: 2 State  Deaths_White  Deaths_Black
# 0    3/7/2021         NaN         NaN    NY         17007          9812
# 1    3/3/2021         NaN         NaN    NY         16855          9714
# 2   2/28/2021         NaN         NaN    NY         16920          9448
# 3   2/24/2021         NaN         NaN    NY         16709          9352
# 4   2/21/2021         NaN         NaN    NY         16562          9283
# 5   2/17/2021         NaN         NaN    NY         16297          9202
# 6   2/14/2021         NaN         NaN    NY         16134          9149
# 7   2/10/2021         NaN         NaN    NY         15843          9039
# 8    2/7/2021         NaN         NaN    NY         15631          8968
# 9    2/3/2021         NaN         NaN    NY         15272          8856
# 10  1/31/2021         NaN         NaN    NY         15049          8817
# 11  1/27/2021         NaN         NaN    NY         14707          8725
# 12  1/24/2021         NaN         NaN    NY         14446          8664
# 13  1/20/2021         NaN         NaN    NY         14061          8587
# 14  1/17/2021         NaN         NaN    NY         13763          8540
# 15  1/13/2021         NaN         NaN    NY         13374          8453
# 16  1/10/2021         NaN         NaN    NY         13125          8393
# 17   1/6/2021         NaN         NaN    NY         12730          8320
# 18   1/3/2021         NaN         NaN    NY         12566          8289

# %% [markdown]
# REMOVE NULL VALUES

# %%
df.isnull()
# Out:
#      Date  Unnamed: 1  Unnamed: 2  State  Deaths_White  Deaths_Black
# 0   False        True        True  False         False         False
# 1   False        True        True  False         False         False
# 2   False        True        True  False         False         False
# 3   False        True        True  False         False         False
# 4   False        True        True  False         False         False
# 5   False        True        True  False         False         False
# 6   False        True        True  False         False         False
# 7   False        True        True  False         False         False
# 8   False        True        True  False         False         False
# 9   False        True        True  False         False         False
# 10  False        True        True  False         False         False
# 11  False        True        True  False         False         False
# 12  False        True        True  False         False         False
# 13  False        True        True  False         False         False
# 14  False        True        True  False         False         False
# 15  False        True        True  False         False         False
# 16  False        True        True  False         False         False
# 17  False        True        True  False         False         False
# 18  False        True        True  False         False         False

# %%
df.notnull()
# Out:
#     Date  Unnamed: 1  Unnamed: 2  State  Deaths_White  Deaths_Black
# 0   True       False       False   True          True          True
# 1   True       False       False   True          True          True
# 2   True       False       False   True          True          True
# 3   True       False       False   True          True          True
# 4   True       False       False   True          True          True
# 5   True       False       False   True          True          True
# 6   True       False       False   True          True          True
# 7   True       False       False   True          True          True
# 8   True       False       False   True          True          True
# 9   True       False       False   True          True          True
# 10  True       False       False   True          True          True
# 11  True       False       False   True          True          True
# 12  True       False       False   True          True          True
# 13  True       False       False   True          True          True
# Index(['Date', 'Unnamed: 1', 'Unnamed: 2', 'State', 'Deaths_White',
#        'Deaths_Black'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of          Date  Unnamed: 1  Unnamed: 2 State  Deaths_White  Deaths_Black
# 0    3/7/2021         NaN         NaN    NY         17007          9812
# 1    3/3/2021         NaN         NaN    NY         16855          9714
# 2   2/28/2021         NaN         NaN    NY         16920          9448
# 3   2/24/2021         NaN         NaN    NY         16709          9352
# 4   2/21/2021         NaN         NaN    NY         16562          9283
# 5   2/17/2021         NaN         NaN    NY         16297          9202
# 6   2/14/2021         NaN         NaN    NY         16134          9149
# 7   2/10/2021         NaN         NaN    NY         15843          9039
# 8    2/7/2021         NaN         NaN    NY         15631          8968
# 9    2/3/2021         NaN         NaN    NY         15272          8856
# 10  1/31/2021         NaN         NaN    NY         15049          8817
# 11  1/27/2021         NaN         NaN    NY         14707          8725
# 12  1/24/2021         NaN         NaN    NY         14446          8664
# 13  1/20/2021         NaN         NaN    NY         14061          8587
# 14  1/17/2021         NaN         NaN    NY         13763          8540
# 15  1/13/2021         NaN         NaN    NY         13374          8453
# 16  1/10/2021         NaN         NaN    NY         13125          8393
# 17   1/6/2021         NaN         NaN    NY         12730          8320
# 18   1/3/2021         NaN         NaN    NY         12566          8289>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of          Date  Unnamed: 1  Unnamed: 2 State  Deaths_White  Deaths_Black
# 0    3/7/2021         NaN         NaN    NY         17007          9812
# 1    3/3/2021         NaN         NaN    NY         16855          9714
# 2   2/28/2021         NaN         NaN    NY         16920          9448
# 3   2/24/2021         NaN         NaN    NY         16709          9352
# 4   2/21/2021         NaN         NaN    NY         16562          9283
# 5   2/17/2021         NaN         NaN    NY         16297          9202
# 6   2/14/2021         NaN         NaN    NY         16134          9149
# 7   2/10/2021         NaN         NaN    NY         15843          9039
# 8    2/7/2021         NaN         NaN    NY         15631          8968
# 9    2/3/2021         NaN         NaN    NY         15272          8856
# 10  1/31/2021         NaN         NaN    NY         15049          8817
# 11  1/27/2021         NaN         NaN    NY         14707          8725
# 12  1/24/2021         NaN         NaN    NY         14446          8664
# 13  1/20/2021         NaN         NaN    NY         14061          8587
# 14  1/17/2021         NaN         NaN    NY         13763          8540
# 15  1/13/2021         NaN         NaN    NY         13374          8453
# 16  1/10/2021         NaN         NaN    NY         13125          8393
# 17   1/6/2021         NaN         NaN    NY         12730          8320
# 18   1/3/2021         NaN         NaN    NY         12566          8289>

# %%
df['Deaths_White'].astype('int')
# Out:
# 0     17007
# 1     16855
# 2     16920
# 3     16709
# 4     16562
# 5     16297
# 6     16134
# 7     15843
# 8     15631
# 9     15272
# 10    15049
# 11    14707
# 12    14446
# 13    14061
# 14    13763
# 15    13374
# 16    13125
# 17    12730
# 18    12566
# Name: Deaths_White, dtype: int64

# %% [markdown]
# Statistical Analysis

# %%
# block 1 - simple stats
mean1 = df['Deaths_Black'].mean()
sum1 = df['Deaths_Black'].sum()
max1 = df['Deaths_Black'].max()
min1 = df['Deaths_Black'].min()
count1 = df['Deaths_Black'].count()
median1 = df['Deaths_Black'].median() 
std1 = df['Deaths_Black'].std() 
var1 = df['Deaths_Black'].var()  

# block 2 - group by
groupby_sum1 = df.groupby(['Deaths_Black']).sum() 
groupby_count1 = df.groupby(['Deaths_Black']).count()

# print block 1
print ('Deaths_Black: ' + str(mean1))
print ('Deaths_Black: ' + str(sum1))
print ('Deaths_Black: ' + str(max1))
print ('Deaths_Black: ' + str(min1))
print ('Deaths_Black: ' + str(count1))
print ('Deaths_Black: ' + str(median1))
print ('Deaths_Black: ' + str(std1))
print ('Deaths_Black: ' + str(var1))

# print block 2
print ('Sum of values, grouped by the Country: ' + str(groupby_sum1))
print ('Count of values, grouped by the Country: ' + str(groupby_count1))
# Out:
# Deaths_Black: 8926.894736842105
# Deaths_Black: 169611
# Deaths_Black: 9812
# Deaths_Black: 8289
# Deaths_Black: 19
# Deaths_Black: 8856.0
# Deaths_Black: 459.3677895563329
# Deaths_Black: 211018.76608187138
# Sum of values, grouped by the Country:               Unnamed: 1  Unnamed: 2  Deaths_White
# Deaths_Black
# 8289                 0.0         0.0         12566
# 8320                 0.0         0.0         12730
# 8393                 0.0         0.0         13125
# 8453                 0.0         0.0         13374
# 8540                 0.0         0.0         13763
# 8587                 0.0         0.0         14061
# 8664                 0.0         0.0         14446
# 8725                 0.0         0.0         14707
# 8817                 0.0         0.0         15049
# 8856                 0.0         0.0         15272
# 8968                 0.0         0.0         15631
# 9039                 0.0         0.0         15843
# 9149                 0.0         0.0         16134
# 9202                 0.0         0.0         16297
# 9283                 0.0         0.0         16562
# 9352                 0.0         0.0         16709
# 9448                 0.0         0.0         16920
# 9714                 0.0         0.0         16855
# 9812                 0.0         0.0         17007
# Count of values, grouped by the Country:               Date  Unnamed: 1  Unnamed: 2  State  Deaths_White
# Deaths_Black
# 8289             1           0           0      1             1
# 8320             1           0           0      1             1
# 8393             1           0           0      1             1
# 8453             1           0           0      1             1
# 8540             1           0           0      1             1
# 8587             1           0           0      1             1
# 8664             1           0           0      1             1
# 8725             1           0           0      1             1
# 8817             1           0           0      1             1
# 8856             1           0           0      1             1
# 8968             1           0           0      1             1
# 9039             1           0           0      1             1
# 9149             1           0           0      1             1
# 9202             1           0           0      1             1
# 9283             1           0           0      1             1
# 9352             1           0           0      1             1
# 9448             1           0           0      1             1
# 9714             1           0           0      1             1
# 9812             1           0           0      1             1

# %% [markdown]
# Bar Chart visualization

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = df['Date']  # .columns('Date')
deaths_white = df['Deaths_White']    # .columns('Deaths_White')
deaths_black = df['Deaths_Black']    # .columns('Deaths_Black')


x = np.arange(len(labels))  # the label locations
width = 0.35 # the width of the bars

fig, ax = plt.subplots(figsize=(25,10))
rects1 = ax.bar(x - width/2, deaths_white, width, label='White')
rects2 = ax.bar(x + width/2, deaths_black, width, label='Black')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of people')
ax.set_xlabel ('Date')
ax.set_title('NY Covid19 Whites vs. Blacks Deaths in 2021')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation= 45)
ax.legend(fontsize= 20)

def autolabel(rects):
  """Attach a text label above each bar in "rects", displaying its heigh. """
  for rect in rects:
      height = rect.get_height()
      ax.annotate('{}'.format(height),
                  xy=(rect.get_x() + rect.get_width() / 2, height), xytext=(0,1), # 3 points vertical offset 
                  textcoords="offset points",
                  ha='center',va='bottom')
      autolabel(rects1)
      autolabel(rects2)

      fig.tight_layout()

      plt.show()
